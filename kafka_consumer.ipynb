# %%
# kafka_consumer.py
from kafka import KafkaConsumer
import json
from time import sleep
import boto3
import uuid
from botocore.exceptions import NoCredentialsError

# %%
consumer = KafkaConsumer('netflix-data', bootstrap_servers=['localhost:9092'],
                         value_deserializer=lambda x: json.loads(x.decode('utf-8')))

# %%
# consumer loop
for message in consumer:
    print(message.value)
# Out:
# {'show_id': 's442', 'type': 'Movie', 'title': 'Fear Street Part 3: 1666', 'director': 'Leigh Janiak', 'cast': '"Kiana Madeira', 'country': ' Ashley Zukerman', 'date_added': ' Gillian Jacobs', 'release_year': ' Olivia Scott Welch', 'rating': ' Benjamin Flores Jr.', 'duration': ' Darrell Britt-Gibson', 'listed_in': ' Sadie Sink', 'description': ' Emily Rudd', 'recommendations': ['Fear Street Part 1: 1994', 'Fear Street Part 2: 1978', 'Brother', 'Vaya', "Devil's Bride"]}
# {'show_id': 's443', 'type': 'TV Show', 'title': 'Johnny Test', 'director': '', 'cast': '"James Arnold Taylor', 'country': ' Trevor Devall', 'date_added': ' Maryke Hendrikse', 'release_year': ' Emily Tennant"', 'rating': '"United States', 'duration': ' Canada"', 'listed_in': '"July 16', 'description': ' 2021"', 'recommendations': ['Motown Magic', 'Someone Like You', 'June & Kopi', 'Post Mortem: No One Dies in Skarnes', 'Dog Gone Trouble']}
# {'show_id': 's444', 'type': 'Movie', 'title': 'La ley de Herodes', 'director': 'Luis Estrada', 'cast': '"Damián Alcázar', 'country': ' Pedro Armendáriz Jr.', 'date_added': ' Delia Casanova', 'release_year': ' Juan Carlos Colombo', 'rating': ' Alex Cox', 'duration': ' Guillermo Gil', 'listed_in': ' Ernesto Gómez Cruz', 'description': ' Leticia Huijara', 'recommendations': ['Justice', 'Long Shot', 'Bordertown', 'Hükümet Kadin', 'Mune: Guardian of the Moon']}
# {'show_id': 's445', 'type': 'TV Show', 'title': 'Naomi Osaka', 'director': 'Garrett Bradley', 'cast': '', 'country': '', 'date_added': '"July 16', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-14', 'listed_in': '1 Season', 'description': 'Docuseries', 'recommendations': ['DNA', 'Holiday Secrets', 'Marked', 'Strongland', 'The Price of Success']}
# {'show_id': 's446', 'type': 'Movie', 'title': 'The Beguiled', 'director': 'Sofia Coppola', 'cast': '"Colin Farrell', 'country': ' Nicole Kidman', 'date_added': ' Kirsten Dunst', 'release_year': ' Elle Fanning', 'rating': ' Oona Laurence', 'duration': ' Angourie Rice', 'listed_in': ' Addison Riecke', 'description': ' Emma Howard"', 'recommendations': ['Dances with Wolves', 'Cold Mountain', 'Lincoln', 'Sword of Trust', 'Fortune Feimster: Sweet & Salty']}
# {'show_id': 's447', 'type': 'Movie', 'title': 'The Book of Henry', 'director': 'Colin Trevorrow', 'cast': '"Naomi Watts', 'country': ' Jaeden Martell', 'date_added': ' Jacob Tremblay', 'release_year': ' Sarah Silverman', 'rating': ' Dean Norris', 'duration': ' Lee Pace', 'listed_in': ' Maddie Ziegler', 'description': ' Tonya Pinkins', 'recommendations': ['Conversations with a Killer: The Ted Bundy Tapes', 'ICarly', 'Turning Point: 9/11 and the War on Terror', "R.L. Stine's Mostly Ghostly", "My Sister's Keeper"]}
# {'show_id': 's448', 'type': 'Movie', 'title': 'The Twilight Saga: Breaking Dawn: Part 1', 'director': 'Bill Condon', 'cast': '"Kristen Stewart', 'country': ' Robert Pattinson', 'date_added': ' Taylor Lautner', 'release_year': ' Billy Burke', 'rating': ' Peter Facinelli', 'duration': ' Elizabeth Reaser', 'listed_in': ' Kellan Lutz', 'description': ' Nikki Reed', 'recommendations': ['The Twilight Saga: Breaking Dawn: Part 2', 'Twilight', 'The Twilight Saga: Eclipse', 'The Twilight Saga: New Moon', 'The Black Room']}
# {'show_id': 's449', 'type': 'Movie', 'title': 'The Twilight Saga: Breaking Dawn: Part 2', 'director': 'Bill Condon', 'cast': '"Kristen Stewart', 'country': ' Robert Pattinson', 'date_added': ' Taylor Lautner', 'release_year': ' Peter Facinelli', 'rating': ' Elizabeth Reaser', 'duration': ' Ashley Greene', 'listed_in': ' Jackson Rathbone', 'description': ' Kellan Lutz', 'recommendations': ['The Twilight Saga: Breaking Dawn: Part 1', 'Twilight', 'The Twilight Saga: Eclipse', 'The Twilight Saga: New Moon', 'Struggle: The Life and Lost Art of Szukalski']}
# {'show_id': 's450', 'type': 'Movie', 'title': 'The Twilight Saga: Eclipse', 'director': 'David Slade', 'cast': '"Kristen Stewart', 'country': ' Robert Pattinson', 'date_added': ' Taylor Lautner', 'release_year': ' Bryce Dallas Howard', 'rating': ' Billy Burke', 'duration': ' Dakota Fanning', 'listed_in': ' Peter Facinelli', 'description': ' Elizabeth Reaser', 'recommendations': ['The Twilight Saga: New Moon', 'Twilight', 'The Twilight Saga: Breaking Dawn: Part 1', 'The Twilight Saga: Breaking Dawn: Part 2', 'Immortals']}
# {'show_id': 's451', 'type': 'Movie', 'title': 'The Twilight Saga: New Moon', 'director': 'Chris Weitz', 'cast': '"Kristen Stewart', 'country': ' Robert Pattinson', 'date_added': ' Taylor Lautner', 'release_year': ' Ashley Greene', 'rating': ' Rachelle Lefevre', 'duration': ' Billy Burke', 'listed_in': ' Michael Sheen', 'description': ' Dakota Fanning', 'recommendations': ['The Twilight Saga: Eclipse', 'Twilight', 'The Twilight Saga: Breaking Dawn: Part 1', 'The Twilight Saga: Breaking Dawn: Part 2', 'You Are My Home']}
# {'show_id': 's452', 'type': 'Movie', 'title': 'Twilight', 'director': 'Catherine Hardwicke', 'cast': '"Kristen Stewart', 'country': ' Robert Pattinson', 'date_added': ' Billy Burke', 'release_year': ' Peter Facinelli', 'rating': ' Elizabeth Reaser', 'duration': ' Cam Gigandet', 'listed_in': ' Ashley Greene', 'description': ' Anna Kendrick', 'recommendations': ['The Twilight Saga: New Moon', 'The Twilight Saga: Eclipse', 'The Twilight Saga: Breaking Dawn: Part 1', 'The Twilight Saga: Breaking Dawn: Part 2', 'The Little Vampire']}
# {'show_id': 's453', 'type': 'Movie', 'title': 'A Perfect Fit', 'director': 'Hadrah Daeng Ratu', 'cast': '"Nadya Arina', 'country': ' Refal Hady', 'date_added': ' Giorgino Abraham', 'release_year': ' Anggika Bolsterli', 'rating': ' Laura Theux', 'duration': ' Christine Hakim', 'listed_in': ' Unique Priscilla', 'description': ' Karina Suwandi', 'recommendations': ['Runaway Bride', 'Love Dot Com: The Social Experiment', 'Galih dan Ratna', "El-Khawaga's Dilemma", 'Hati Perempuan']}
# {'show_id': 's454', 'type': 'TV Show', 'title': 'BEASTARS', 'director': '', 'cast': '"Chikahiro Kobayashi', 'country': ' Sayaka Senbongi', 'date_added': ' Yuki Ono', 'release_year': ' Atsumi Tanezaki', 'rating': ' Junya Enoki', 'duration': ' Yuma Uchida', 'listed_in': ' Takeo Otsuka', 'description': ' Naoto Kobayashi', 'recommendations': ['How I Became a Superhero', 'Alpha and Omega: The Legend of the Saw Tooth Cave', 'Welcome to Monster High: The Origin Story', 'Hospital Playlist', 'Balto 2: Wolf Quest']}
# {'show_id': 's455', 'type': 'Movie', 'title': "Cheech & Chong's Still Smokin", 'director': 'Tommy Chong', 'cast': '"Cheech Marin', 'country': ' Tommy Chong', 'date_added': ' Susan Hahn', 'release_year': ' Carol van Herwijnen', 'rating': ' Shireen Strooker"', 'duration': '', 'listed_in': '"July 15', 'description': ' 2021"', 'recommendations': ['The Wrong Missy', 'Pocoyo & The Space Circus', 'Tiny Pretty Things', 'Zona Rosa', 'Martyrs of Marriage']}
# {'show_id': 's456', 'type': 'Movie', 'title': 'Emicida: AmarElo - Live in São Paulo', 'director': 'Fred Ouro Preto', 'cast': 'Emicida', 'country': '', 'date_added': '"July 15', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-MA', 'listed_in': '100 min', 'description': '"Documentaries', 'recommendations': ['Emicida: AmarElo - It’s All For Yesterday', 'Sintonia', 'Spectros', 'The Birth Reborn 3', 'Back and Forth']}
# {'show_id': 's457', 'type': 'TV Show', 'title': 'Her Private Life', 'director': '', 'cast': '"Park Min-young', 'country': ' Kim Jae-uk', 'date_added': ' Ahn Bo-hyun', 'release_year': ' Jung Je-won', 'rating': ' Park Jin-joo', 'duration': ' Kim Bo-ra', 'listed_in': ' Maeng Sang-hun', 'description': ' Kim Mee-kyung', 'recommendations': ['High Society', '27, el club de los malditos', 'Made You Look: A True Story About Fake Art', 'Dry Martina', 'Super Me']}
# {'show_id': 's458', 'type': 'Movie', 'title': 'Lift Like a Girl', 'director': 'Mayye Zayed', 'cast': '', 'country': '"Egypt', 'date_added': ' Denmark', 'release_year': ' Germany"', 'rating': '"July 15', 'duration': ' 2021"', 'listed_in': '2021', 'description': 'TV-PG', 'recommendations': ['Luccas Neto em: Acampamento de Férias 2', 'The Decline', 'Kahaani', '23:59', 'Friday Night Lights']}
# {'show_id': 's459', 'type': 'Movie', 'title': 'My Amanda', 'director': 'Alessandra de Rossi', 'cast': '"Piolo Pascual', 'country': ' Alessandra de Rossi', 'date_added': ' KC Montero', 'release_year': ' Alex Medina', 'rating': ' Jess Mendoza', 'duration': ' Helga Krapf', 'listed_in': ' Joyce Ann Burton', 'description': ' Luz Valdez"', 'recommendations': ['Graceful Friends', 'Unlucky Ploy', 'Leyla and Mecnun', 'Salaakhen', 'The Perfect Picture: Ten Years Later']}
# {'show_id': 's460', 'type': 'TV Show', 'title': 'Never Have I Ever', 'director': '', 'cast': '"Maitreyi Ramakrishnan', 'country': ' Poorna Jagannathan', 'date_added': ' Richa Moorjani', 'release_year': ' Jaren Lewison', 'rating': ' Darren Barnet', 'duration': ' John McEnroe', 'listed_in': ' Ramona Young', 'description': ' Lee Rodriguez', 'recommendations': ['Zack and Miri Make a Porno', 'Mean Girls 2', 'Reply 1997', 'Yu-Gi-Oh! Arc-V', "Love Don't Cost a Thing"]}
# {'show_id': 's461', 'type': 'Movie', 'title': "Surf's Up", 'director': '"Ash Brannon', 'cast': ' Chris Buck"', 'country': '"Shia LaBeouf', 'date_added': ' Jeff Bridges', 'release_year': ' Zooey Deschanel', 'rating': ' Jon Heder', 'duration': ' James Woods', 'listed_in': ' Diedrich Bader', 'description': ' Mario Cantone', 'recommendations': ['The Tribes of Palos Verdes', 'Bethany Hamilton: Unstoppable', 'Soul Surfer', 'Two Distant Strangers', 'WWII: Report from the Aleutians']}
# {'show_id': 's462', 'type': 'Movie', 'title': 'The Unknown Saint', 'director': 'Alaa Eddine Aljem', 'cast': '"Younes Bouab', 'country': ' Salah Bensalah', 'date_added': ' Bouchaib Essamak', 'release_year': ' Mohamed Naimane', 'rating': ' Anas Elbaz', 'duration': ' Hassan Ben Badida', 'listed_in': ' Abdelghani Kitab', 'description': ' Ahmed Yarziz', 'recommendations': ['Blue Streak', 'The Saint', 'Legal Hash', 'Cradle 2 the Grave', 'An Ordinary Man']}
# {'show_id': 's463', 'type': 'Movie', 'title': 'This Changes Everything', 'director': 'Tom Donahue', 'cast': '', 'country': 'United States', 'date_added': '"July 15', 'release_year': ' 2021"', 'rating': '2019', 'duration': 'TV-MA', 'listed_in': '96 min', 'description': 'Documentaries', 'recommendations': ['What the F* Is Going On?', 'Liberated: The New Sexual Revolution', 'Hollywood', 'Five Came Back', 'The Barrier']}
# {'show_id': 's464', 'type': 'Movie', 'title': 'A Classic Horror Story', 'director': '"Roberto De Feo', 'cast': ' Paolo Strippoli"', 'country': '"Matilda Lutz', 'date_added': ' Francesco Russo', 'release_year': ' Peppino Mazzotta', 'rating': ' Will Merrick', 'duration': ' Yuliia Sobol', 'listed_in': ' Alida Baldari Calabria', 'description': ' Cristina Donadio', 'recommendations': ['The Binding', 'Girls With Balls', '7:19', 'Rust Creek', 'Fear Street Part 2: 1978']}
# {'show_id': 's465', 'type': 'Movie', 'title': 'Gunpowder Milkshake', 'director': 'Navot Papushado', 'cast': '"Karen Gillan', 'country': ' Lena Headey', 'date_added': ' Carla Gugino', 'release_year': ' Chloe Coleman', 'rating': ' Michelle Yeoh', 'duration': ' Angela Bassett', 'listed_in': ' Paul Giamatti', 'description': ' Ralph Ineson', 'recommendations': ['Silencer', 'The Prison', 'Scissor Seven', 'The Bund', 'Jim Jefferies : BARE']}
# {'show_id': 's466', 'type': 'TV Show', 'title': 'Heist', 'director': '', 'cast': '', 'country': '', 'date_added': '"July 14', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-MA', 'listed_in': '1 Season', 'description': '"Crime TV Shows', 'recommendations': ['Kon Kon Kon', 'Yo-Kai Watch: The Movie', 'Chhota Bheem: Dus Pe Dus', 'The Prison', 'Thunder Force']}
# {'show_id': 's467', 'type': 'TV Show', 'title': 'My Unorthodox Life', 'director': '', 'cast': '', 'country': '', 'date_added': '"July 14', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-MA', 'listed_in': '1 Season', 'description': 'Reality TV', 'recommendations': ['One of Us', 'Shtisel', 'The Awakening of Motti Wolkenbruch', 'Super Drags', 'Pet Stars']}
# {'show_id': 's468', 'type': 'Movie', 'title': 'Private Network: Who Killed Manuel Buendía?', 'director': 'Manuel Alcalá', 'cast': 'Daniel Giménez Cacho', 'country': '', 'date_added': '"July 14', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-MA', 'listed_in': '100 min', 'description': '"Documentaries', 'recommendations': ['Vanjagar Ulagam', 'Black Beach', 'Close Enemies', 'RIDE ON TIME', '(Un)Well']}
# {'show_id': 's469', 'type': 'Movie', 'title': 'The Guide to the Perfect Family', 'director': 'Ricardo Trogi', 'cast': '"Louis Morissette', 'country': ' Émilie Bierre', 'date_added': ' Catherine Chabot', 'release_year': ' Xavier Lebel', 'rating': ' Isabelle Guérard', 'duration': ' Gilles Renaud', 'listed_in': ' Alexandre Goyette', 'description': ' Jean-Carl Boucher', 'recommendations': ["Tom Papa: You're Doing Great!", 'Limitless', 'The Terminal', 'Almost Happy', 'The Hater']}
# {'show_id': 's470', 'type': 'Movie', 'title': 'American Woman', 'director': 'Semi Chellas', 'cast': '"Hong Chau', 'country': ' Sarah Gadon', 'date_added': ' John Gallagher Jr.', 'release_year': ' Lola Kirke', 'rating': ' Ellen Burstyn', 'duration': ' David Cubitt', 'listed_in': ' Jordan Pettle', 'description': ' Richard Walters"', 'recommendations': ['Sex and the City: The Movie', 'My Only Mother', 'Revenge', 'Coin Heist', 'Finding Agnes']}
# {'show_id': 's471', 'type': 'Movie', 'title': 'Bridgerton - The Afterparty', 'director': '', 'cast': '"David Spade', 'country': ' London Hughes', 'date_added': ' Fortune Feimster"', 'release_year': '', 'rating': '"July 13', 'duration': ' 2021"', 'listed_in': '2021', 'description': 'TV-14', 'recommendations': ['Nikki Glaser: Bangin’', 'The Road to El Camino: Behind the Scenes of El Camino: A Breaking Bad Movie', 'Ginny & Georgia - The Afterparty', 'To All the Boys: Always and Forever - The Afterparty', 'Oprah Presents When They See Us Now']}
# {'show_id': 's472', 'type': 'Movie', 'title': 'Day of Destiny', 'director': '"Akay Mason', 'cast': ' Abosi Ogba"', 'country': '"Olumide Oworu', 'date_added': ' Denola Grey', 'release_year': ' Gbemi Akinlade', 'rating': ' Jide Kosoko', 'duration': ' Ireti Doyle', 'listed_in': ' Norbert Young', 'description': ' Toyin Abraham', 'recommendations': ['Zindagi Kitni Haseen Hay', 'SAS: Rise of the Black Swan', 'Nacho Libre', 'Bangkok Buddies', 'Because This Is My First Life']}
# {'show_id': 's473', 'type': 'TV Show', 'title': 'Ridley Jones', 'director': '', 'cast': '"Iara Nemirovsky', 'country': ' Laraine Newman', 'date_added': ' David Errigo Jr', 'release_year': ' Tyler Shamy', 'rating': ' Ezra Menas', 'duration': ' Ashlyn Madden', 'listed_in': ' Sutton Foster"', 'description': 'United States', 'recommendations': ['Sid the Science Kid', 'Blood & Treasures', 'Chhota Bheem - Dinosaur World', "Motu Patlu in Dragon's World", 'You Get Me']}
# {'show_id': 's474', 'type': 'Movie', 'title': 'Born to Play', 'director': 'Viridiana Lieberman', 'cast': '', 'country': 'United States', 'date_added': '"July 12', 'release_year': ' 2021"', 'rating': '2020', 'duration': 'TV-MA', 'listed_in': '93 min', 'description': '"Documentaries', 'recommendations': ['Undefeated', 'The Last Boy Scout', 'Fairy Tail', 'The Match', 'Game Over (Telugu Version)']}
# {'show_id': 's475', 'type': 'Movie', 'title': 'American Ultra', 'director': 'Nima Nourizadeh', 'cast': '"Jesse Eisenberg', 'country': ' Kristen Stewart', 'date_added': ' Topher Grace', 'release_year': ' Connie Britton', 'rating': ' Walton Goggins', 'duration': ' John Leguizamo', 'listed_in': ' Bill Pullman', 'description': ' Tony Hale', 'recommendations': ["Dante's Peak", 'Larceny', 'Aliens Stole My Body', 'Mississippi Grind', 'She']}
# {'show_id': 's476', 'type': 'Movie', 'title': 'The Stand-Up', 'director': 'Daniel Růžička', 'cast': '"Iva Pazderková', 'country': ' Lukáš Pavlásek', 'date_added': ' Daniel Čech', 'release_year': ' Petr Cerha', 'rating': ' Ondřej Havlík', 'duration': ' Radek Petráš', 'listed_in': ' Zbyněk Vičar', 'description': ' Pavel Tomeš', 'recommendations': ['Ray Romano: Right Here, Around the Corner', 'Monty Python: Live at Aspen', "Kevin Hart: I'm a Grown Little Man", 'Rob Schneider: Asian Momma, Mexican Kids', 'The Comedy Lineup']}
# {'show_id': 's477', 'type': 'Movie', 'title': 'The Tour', 'director': 'Juraj Šajmovič', 'cast': '"Miloš Knor', 'country': ' Lukáš Pavlásek', 'date_added': ' Tomáš Matonoha', 'release_year': ' Ester Kočičková', 'rating': ' Michal Kavalčík', 'duration': ' Richard Nedvěd"', 'listed_in': '', 'description': '"July 10', 'recommendations': ['The First Temptation of Christ', 'The Great Heist', 'Jo Koy: In His Elements', 'Joker', 'The Lost Pirate Kingdom']}
# {'show_id': 's478', 'type': 'TV Show', 'title': 'Atypical', 'director': '', 'cast': '"Jennifer Jason Leigh', 'country': ' Keir Gilchrist', 'date_added': ' Michael Rapaport', 'release_year': ' Brigette Lundy-Paine', 'rating': ' Amy Okuda', 'duration': ' Jenna Boyd', 'listed_in': ' Graham Rogers', 'description': ' Nik Dodani"', 'recommendations': ["Asperger's Are Us", 'Love on the Spectrum', 'The Night Clerk', 'Queen', 'Irada Pakka']}
# {'show_id': 's479', 'type': 'TV Show', 'title': 'Biohackers', 'director': '', 'cast': '"Luna Wedler', 'country': ' Jessica Schwarz', 'date_added': ' Adrian Julius Tillmann', 'release_year': ' Thomas Prenn', 'rating': ' Jing Xiang', 'duration': ' Caro Cult', 'listed_in': ' Sebastian Jakob Doppelbauer"', 'description': 'Germany', 'recommendations': ['American Odyssey', '1983', 'High & Low The Red Rain', 'Ankur Arora Murder Case', 'Feb-09']}
# {'show_id': 's480', 'type': 'Movie', 'title': 'Fear Street Part 2: 1978', 'director': 'Leigh Janiak', 'cast': '"Sadie Sink', 'country': ' Emily Rudd', 'date_added': ' Ryan Simpkins', 'release_year': ' McCabe Slye', 'rating': ' Ted Sutherland', 'duration': ' Jordana Spiro', 'listed_in': ' Gillian Jacobs', 'description': ' Kiana Madeira', 'recommendations': ['Fear Street Part 1: 1994', 'All Good Ones Get Away', "Bunk'd", 'Godless', 'Fear Street Part 3: 1666']}
# {'show_id': 's481', 'type': 'Movie', 'title': 'Finding Hubby', 'director': 'Femi D. Ogunsanwo', 'cast': '"Ade Laoye', 'country': ' Munachi Abii', 'date_added': ' Kehinde Bankole', 'release_year': ' Charles Etubiebi', 'rating': ' Paul Utomi', 'duration': ' Efa Iwara', 'listed_in': ' Tina Mba', 'description': ' Tope Tedela', 'recommendations': ['Takki', 'The Perfect Picture: Ten Years Later', 'College Romance', 'Can You Hear Me?', 'Grace and Frankie']}
# {'show_id': 's482', 'type': 'Movie', 'title': 'How I Became a Superhero', 'director': 'Douglas Attal', 'cast': '"Pio Marmaï', 'country': ' Vimala Pons', 'date_added': ' Benoît Poelvoorde', 'release_year': ' Leïla Bekhti', 'rating': ' Swann Arlaud', 'duration': ' Gilles Cohen', 'listed_in': ' Léonie Souchaud', 'description': ' Camille Japy', 'recommendations': ['The Happytime Murders', 'BEASTARS', 'Rampage: President Down', 'Balto 2: Wolf Quest', 'Skin Trade']}
# {'show_id': 's483', 'type': 'TV Show', 'title': 'How to Become a Tyrant', 'director': '', 'cast': 'Peter Dinklage', 'country': '', 'date_added': '"July 9', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-MA', 'listed_in': '1 Season', 'description': 'Docuseries', 'recommendations': ["Marvel's Iron Fist", 'Valentino', "Marvel's The Defenders", 'Maid-Sama!', 'Pitaah']}
# {'show_id': 's484', 'type': 'Movie', 'title': 'Last Summer', 'director': '', 'cast': '"Fatih Şahin', 'country': ' Ece Çeşmioğlu', 'date_added': ' Halit Özgür Sarı', 'release_year': ' Aslıhan Malbora', 'rating': ' Eray Ertüren', 'duration': ' Eren Ören', 'listed_in': ' Ozan Kaya Oktu', 'description': ' Talha Öztürk', 'recommendations': ['Find Yourself', 'Free Rein', 'Oh, Ramona!', 'Kocan Kadar Konus', 'Secreto bien guardado']}
# {'show_id': 's485', 'type': 'Movie', 'title': 'Lee Su-geun: The Sense Coach', 'director': 'Kim Joo-hyung', 'cast': 'Lee Su-geun', 'country': '', 'date_added': '"July 9', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-G', 'listed_in': '46 min', 'description': 'Stand-Up Comedy', 'recommendations': ['Hera Pheri', 'El Viaje: Márama y Rombai', 'Unlucky Ploy', 'Good Morning Call', 'Super Monsters: Santa’s Super Monster Helpers']}
# {'show_id': 's486', 'type': 'Movie', 'title': 'Lethal Love', 'director': 'Avi Federgreen', 'cast': '"David Pinard', 'country': ' Joelle Farrow', 'date_added': ' Torri Higginson', 'release_year': ' Tommie-Amber Pirie"', 'rating': '', 'duration': '"July 9', 'listed_in': ' 2021"', 'description': '2021', 'recommendations': ['Zoo', 'Rajnigandha', 'The Last Laugh', 'Sandy Wexler', 'Pose']}
# {'show_id': 's487', 'type': 'Movie', 'title': 'Ratchet and Clank', 'director': '"Jericca Cleland', 'cast': ' Kevin Munroe"', 'country': '"Paul Giamatti', 'date_added': ' John Goodman', 'release_year': ' Bella Thorne', 'rating': ' Rosario Dawson', 'duration': ' Jim Ward', 'listed_in': ' Armin Shimerman', 'description': ' Vincent Tong', 'recommendations': ['Alien Worlds', 'Power Rangers Samurai: Clash of the Red Rangers', 'Home', 'Stargate SG-1', 'Naruto Shippuden: The Movie: The Lost Tower']}
# {'show_id': 's488', 'type': 'TV Show', 'title': 'The Cook of Castamar', 'director': '', 'cast': '"Michelle Jenner', 'country': ' Roberto Enríquez', 'date_added': ' Hugo Silva', 'release_year': ' Maxi Iglesias', 'rating': ' María Hervás', 'duration': ' Agnès Llobet', 'listed_in': ' Paula Usero', 'description': ' Jean Cruz', 'recommendations': ['In Family I Trust', 'Dancing Queens', 'So Much Love to Give', 'Motichoor Chaknachoor', 'Fitoor']}
# {'show_id': 's489', 'type': 'TV Show', 'title': 'Virgin River', 'director': '', 'cast': '"Alexandra Breckenridge', 'country': ' Martin Henderson', 'date_added': ' Tim Matheson', 'release_year': " Annette O'Toole", 'rating': ' Colin Lawrence', 'duration': ' Jenny Cooper', 'listed_in': ' Lauren Hammersley"', 'description': 'United States', 'recommendations': ['Family Blood', 'The Strange House', 'Welcome to Willits', 'The Haunting of Molly Hartley', 'A Haunted House 2']}
# {'show_id': 's490', 'type': 'Movie', 'title': 'Back to Q82', 'director': 'Ahmed Siddiqui', 'cast': '"Jassim Al Nabhan', 'country': ' Abdel Imam Abdullah', 'date_added': ' Abdulaziz El Nassar', 'release_year': ' Khalid Muthafar', 'rating': ' Amal Anbari', 'duration': ' Ali Al-Hamdaan', 'listed_in': ' El Hussein Abd', 'description': ' Nawaf Al Shemmeri', 'recommendations': ['The Time Machine', 'Four Christmases', 'Love Storm', 'Ginny Weds Sunny', 'Chitty Chitty Bang Bang']}
# {'show_id': 's491', 'type': 'TV Show', 'title': 'Elize Matsunaga: Once Upon a Crime', 'director': '', 'cast': '', 'country': '', 'date_added': '"July 8', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-MA', 'listed_in': '1 Season', 'description': '"Crime TV Shows', 'recommendations': ['Friday Night Tykes', 'Enter the Anime', 'Duniya', 'High Score', 'Kurbaan']}
# {'show_id': 's492', 'type': 'Movie', 'title': 'Home Again', 'director': 'Hallie Meyers-Shyer', 'cast': '"Reese Witherspoon', 'country': ' Michael Sheen', 'date_added': ' Candice Bergen', 'release_year': ' Nat Wolff', 'rating': ' Jon Rudnitsky', 'duration': ' Pico Alexander', 'listed_in': ' Lake Bell', 'description': ' Reid Scott', 'recommendations': ['3 Generations', 'Welcome to the Family', 'One Day at a Time', 'Tribhanga - Tedhi Medhi Crazy', 'Justine']}
# {'show_id': 's493', 'type': 'Movie', 'title': 'Midnight Sun', 'director': 'Scott Speer', 'cast': '"Bella Thorne', 'country': ' Patrick Schwarzenegger', 'date_added': ' Rob Riggle', 'release_year': ' Quinn Shephard', 'rating': ' Suleka Mathew', 'duration': ' Tiera Skovbye', 'listed_in': ' Ken Tremblett', 'description': ' Norm Misura', 'recommendations': ['The Lion Woman', 'Plaire, aimer et courir vite', 'Kipo and the Age of Wonderbeasts', 'Use For My Talent', 'Gatao - The Last Stray']}
# {'show_id': 's494', 'type': 'TV Show', 'title': 'RESIDENT EVIL: Infinite Darkness', 'director': '', 'cast': '"Nick Apostolides', 'country': ' Stephanie Panisello', 'date_added': ' Ray Chase', 'release_year': ' Jona Xiao', 'rating': ' Billy Kametz', 'duration': ' Joe J. Thomas', 'listed_in': ' Doug Stone', 'description': ' Brad Venable', 'recommendations': ['The Block Island Sound', 'Ragini MMS 2', 'Olympus Has Fallen', 'Paranoid', "Lee Daniels' The Butler"]}
# {'show_id': 's495', 'type': 'Movie', 'title': 'Rock the Kasbah', 'director': 'Barry Levinson', 'cast': '"Bill Murray', 'country': ' Kate Hudson', 'date_added': ' Zooey Deschanel', 'release_year': ' Danny McBride', 'rating': ' Scott Caan', 'duration': ' Leem Lubany', 'listed_in': ' Bruce Willis', 'description': ' Arian Moayed', 'recommendations': ['The Aerial', '45 rpm', 'LoliRock', 'The Liar and His Lover', 'Part-Time Idol']}
# {'show_id': 's496', 'type': 'Movie', 'title': 'Awon Boyz', 'director': 'Tolulope Itegboje', 'cast': '', 'country': '', 'date_added': '"July 7', 'release_year': ' 2021"', 'rating': '2019', 'duration': 'TV-MA', 'listed_in': '38 min', 'description': '"Documentaries', 'recommendations': ['HQ Barbers', 'The Lost Okoroshi', 'Fifty', 'Love and Hong Kong', 'Highly Strung']}
# {'show_id': 's497', 'type': 'Movie', 'title': 'Brick Mansions', 'director': 'Camille Delamarre', 'cast': '"Paul Walker', 'country': ' David Belle', 'date_added': ' RZA', 'release_year': ' Gouchy Boy', 'rating': ' Catalina Denis', 'duration': ' Ayisha Issa', 'listed_in': ' Carlo Rota', 'description': ' Andreas Apergis', 'recommendations': ['Undercover', 'Blood Father', 'Motel Makeover', 'Deuces', 'The Prison']}
# {'show_id': 's498', 'type': 'TV Show', 'title': 'Cat People', 'director': '', 'cast': '', 'country': '', 'date_added': '"July 7', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-14', 'listed_in': '1 Season', 'description': 'Docuseries', 'recommendations': ['Stuart Little', '#cats_the_mewvie', 'Haunted: Latin America', 'Catwalk: Tales from the Cat Show Circuit', 'Home Game']}
# {'show_id': 's499', 'type': 'Movie', 'title': 'Clash', 'director': 'Pascal Atuma', 'cast': '"Omoni Oboli', 'country': ' Brian Hooks', 'date_added': ' Stephanie Linus', 'release_year': ' Merlisa Determined', 'rating': ' Pascal Atuma', 'duration': ' Derel Isaac', 'listed_in': ' Naima Sundiata', 'description': ' Chealse Howell', 'recommendations': ['Meet the Adebanjos', 'The Indian Detective', 'Virsa', 'The Terminal', 'Yaara O Dildaara']}
# {'show_id': 's500', 'type': 'TV Show', 'title': 'Dogs', 'director': '', 'cast': '', 'country': 'United States', 'date_added': '"July 7', 'release_year': ' 2021"', 'rating': '2021', 'duration': 'TV-PG', 'listed_in': '2 Seasons', 'description': 'Docuseries', 'recommendations': ['Kon Kon Kon', 'LEGO Jurassic World: The Indominus Escape', 'Diamonds in the Sky', "Don't be the First one", 'Dhobi Ghat (Mumbai Diaries)']}
# {'show_id': 's501', 'type': 'Movie', 'title': 'Major Grom: Plague Doctor', 'director': 'Oleg Trofim', 'cast': '"Tikhon Zhiznevskiy', 'country': ' Lyubov Aksyonova', 'date_added': ' Alexei Maklakov', 'release_year': ' Aleksandr Seteykin', 'rating': ' Sergei Goroshko', 'duration': ' Dmitriy Chebotarev', 'listed_in': ' Mikhail Evlanov', 'description': ' Oleg Chugunov', 'recommendations': ['Ranbhool', 'Malang', 'Skiptrace', 'Code Lyoko', 'High-Rise Invasion']}
# {'show_id': 's502', 'type': 'Movie', 'title': 'Mama Drama', 'director': 'Seyi Babatope', 'cast': '"Osas Ighodaro', 'country': ' Kunle Remi', 'date_added': ' Kehinde Bankole', 'release_year': ' Femi Adebayo', 'rating': ' Shaffy Bello', 'duration': ' Adunni Ade', 'listed_in': ' Chinyere Wilfred', 'description': ' Olive Emodi', 'recommendations': ['I Fine... Thank You... Love You', 'What We Wanted', 'Mimi', 'Thi Mai', 'The Rational Life']}
# {'show_id': 's503', 'type': 'Movie', 'title': 'Tango With Me', 'director': 'Mahmood Ali-Balogun', 'cast': '"Genevieve Nnaji', 'country': ' Joseph Benjamin', 'date_added': ' Joke Silva', 'release_year': ' Tina Mba', 'rating': ' Ahmed Yerima', 'duration': ' Bimbo Manuel', 'listed_in': ' Sade Alder-Hayes"', 'description': 'Nigeria', 'recommendations': ['Mundina Nildana', 'دفعة القاهرة', 'Ex-Boyfriend', 'The Body Remembers When the World Broke Open', 'Falsa identidad']}
# {'show_id': 's504', 'type': 'TV Show', 'title': 'The Mire', 'director': 'Jan Holoubek', 'cast': '"Andrzej Seweryn', 'country': ' Dawid Ogrodnik', 'date_added': ' Zofia Wichłacz', 'release_year': ' Magdalena Walach', 'rating': ' Piotr Fronczewski', 'duration': ' Agnieszka Żulewska', 'listed_in': ' Ireneusz Czop', 'description': ' Zbigniew Waleryś', 'recommendations': ['Samarppanam', 'Scandal', 'My True Friend', 'Bobby Jasoos', 'Manoranjan']}
# {'show_id': 's505', 'type': 'TV Show', 'title': 'The War Next-door', 'director': '', 'cast': '"Vanessa Bauche', 'country': ' Ana Layevska', 'date_added': ' Mark Tacher', 'release_year': ' Pascacio López', 'rating': ' Elyfer Torres', 'duration': ' Armando Said', 'listed_in': ' Christian Vazquez', 'description': ' Marco León', 'recommendations': ['Reply 1988', 'Triple Frontier', 'Best Neighbors', 'The School of Mischief', "Because We're Heading Out"]}
# {'show_id': 's506', 'type': 'Movie', 'title': 'Therapy', 'director': '"Anurin Nwunembom', 'cast': ' Musing Derrick"', 'country': '"Richard Mofe-Damijo', 'date_added': ' Ireti Doyle', 'release_year': ' Ermelinde Simo Sakah Jing', 'rating': ' Alenne Menget', 'duration': ' Syndy Emade', 'listed_in': ' Lucie Memba Boss', 'description': ' Neba Godwill Awantu', 'recommendations': ['Psiconautas', 'They Are Everywhere', 'Band Aid', 'Sin City', 'Bliss']}
# {'show_id': 's507', 'type': 'Movie', 'title': 'This Little Love Of Mine', 'director': 'Christine Luby', 'cast': '"Saskia Hampele', 'country': ' Liam McIntyre', 'date_added': ' Lynn Gilmartin', 'release_year': ' Craig Horner"', 'rating': 'Australia', 'duration': '"July 7', 'listed_in': ' 2021"', 'description': '2021', 'recommendations': ['Black Snow', 'Last Ferry', 'Dark Skies', '2 Weeks in Lagos', 'Love Like the Falling Rain']}
# {'show_id': 's508', 'type': 'Movie', 'title': 'Three Thieves', 'director': 'Udoka Oyeka', 'cast': '"Koye Kekere Ekun', 'country': ' Shawn Faqua', 'date_added': ' Frank Donga', 'release_year': ' Lucianne Akpabio', 'rating': ' Shaffy Bello', 'duration': ' Angel Unigwe', 'listed_in': ' Kalu Ikeagwu', 'description': ' Enado Odigie', 'recommendations': ['Khosla Ka Ghosla', 'The Shaukeens', 'World Famous Lover', 'AlphaGo', 'Thug Life']}
# {'show_id': 's509', 'type': 'Movie', 'title': 'A Land Imagined', 'director': 'Yeo Siew Hua', 'cast': '"Peter Yu', 'country': ' Liu Xiaoyi', 'date_added': ' Guo Yue', 'release_year': ' Ishtiaque Zico', 'rating': ' Jack Tan"', 'duration': '"France', 'listed_in': ' Netherlands', 'description': ' Singapore"', 'recommendations': ['A Yellow Bird', 'Udta Punjab', 'Paranormal Investigation', 'Awake: The Million Dollar Game', "God's Own Country"]}
# {'show_id': 's510', 'type': 'TV Show', 'title': 'Ask the StoryBots', 'director': '', 'cast': '"Judy Greer', 'country': ' Erin Fitzgerald', 'date_added': ' Fred Tatasciore', 'release_year': ' Jeff Gill', 'rating': ' Gregg Spiridellis', 'duration': ' Evan Spiridellis"', 'listed_in': 'United States', 'description': '"July 6', 'recommendations': ['Fun Mom Dinner', 'A StoryBots Space Adventure', 'The Pyramid Code', 'My Little Pony Equestria Girls: Legend of Everfree', 'Sid the Science Kid']}
# {'show_id': 's511', 'type': 'TV Show', 'title': 'Between', 'director': '', 'cast': '"Jennette McCurdy', 'country': ' Jesse Carere', 'date_added': ' Ryan Allen', 'release_year': ' Justin Kelly', 'rating': ' Kyle Mac', 'duration': ' Jack Murray', 'listed_in': ' Brooke Palsson', 'description': ' Jim Watson', 'recommendations': ['Occupation', 'Pihu', 'Michael', 'The Journey Is the Destination', 'Dead in a Week (Or Your Money Back)']}
# {'show_id': 's512', 'type': 'TV Show', 'title': 'Chelsea', 'director': '', 'cast': '', 'country': 'United States', 'date_added': '"July 6', 'release_year': ' 2021"', 'rating': '2017', 'duration': 'TV-MA', 'listed_in': '2 Seasons', 'description': '"Stand-Up Comedy & Talk Shows', 'recommendations': ['Kevin Hart: Seriously Funny', 'Chelsea Does', 'Dolly Parton: Here I Am', 'Dream Home Makeover', 'Cat People']}
# {'show_id': 's513', 'type': 'TV Show', 'title': 'Code Lyoko', 'director': '', 'cast': '"Raphaelle Bruneau', 'country': ' Sophie Landresse', 'date_added': ' Marie-Line Landerwyn', 'release_year': ' Géraldine Frippiat', 'rating': ' Carole Baillien', 'duration': ' Bruno Mullenaerts', 'listed_in': ' Frédéric Meaux"', 'description': '"France', 'recommendations': ['Satria Heroes: Revenge of the Darkness', 'The Writer', 'Power Rangers Beast Morphers', 'Major Grom: Plague Doctor', 'Little Singham: Kaal Ka Badla']}
# {'show_id': 's514', 'type': 'TV Show', 'title': 'Colony', 'director': '', 'cast': '"Josh Holloway', 'country': ' Sarah Wayne Callies', 'date_added': ' Peter Jacobson', 'release_year': ' Amanda Righetti', 'rating': ' Tory Kittles', 'duration': ' Isabella Crovetti', 'listed_in': ' Alex Neustaedter"', 'description': 'United States', 'recommendations': ['Arrested Development', 'Delhi 6', 'Lockout', 'Rabbids Invasion', 'The Father Who Moves Mountains']}
# {'show_id': 's515', 'type': 'TV Show', 'title': 'Cuckoo', 'director': '', 'cast': '"Andy Samberg', 'country': ' Taylor Lautner', 'date_added': ' Greg Davies', 'release_year': ' Helen Baxendale', 'rating': ' Tamla Kari', 'duration': ' Tyger Drew-Honey', 'listed_in': ' Esther Smith"', 'description': 'United Kingdom', 'recommendations': ['Grace and Frankie', 'Double Dad', 'Super Monsters Monster Pets', 'The Rachel Divide', 'Over Christmas']}
# {'show_id': 's516', 'type': 'TV Show', 'title': 'Derry Girls', 'director': '', 'cast': '"Saoirse-Monica Jackson', 'country': ' Nicola Coughlan', 'date_added': ' Louisa Harland', 'release_year': " Jamie-Lee O'Donnell", 'rating': ' Dylan Llewellyn', 'duration': " Tara Lynne O'Neill", 'listed_in': ' Kathy Kiera Clarke', 'description': ' Tommy Tiernan', 'recommendations': ['Heartbreak High', 'Degrassi: Next Class', '100 Things to do Before High School', 'Back to the 90s', 'Angel Beats!']}
# {'show_id': 's517', 'type': 'TV Show', 'title': 'Girl from Nowhere', 'director': '', 'cast': '"Chicha Amatayakul', 'country': ' Thanawetch Siriwattanakul', 'date_added': ' Pajaree Nantarat', 'release_year': ' Thitinan Khlangphet', 'rating': ' Chonnikan Netjui', 'duration': ' Nutthasit Kotimanuswanich', 'listed_in': ' Tatchapol Thitiapichai', 'description': ' Chanicha Boonpanuvichit', 'recommendations': ['Misfit 2', 'Bruno and Boots: The Wizzle War', 'The Mad Monk', 'Kay Dyache Bola', 'Liar, Liar, Vampire']}
# {'show_id': 's518', 'type': 'TV Show', 'title': 'Good Morning Call', 'director': '', 'cast': '"Haruka Fukuhara', 'country': ' Shunya Shiraishi', 'date_added': ' Dori Sakurada', 'release_year': ' Moe Arai', 'rating': ' Kentaro', 'duration': ' Shugo Nagashima', 'listed_in': ' Koya Nagasawa', 'description': ' Hinako Tanaka', 'recommendations': ['Misfit', 'Miss in Kiss', 'Raising Victor Vargas', "What's Up With Love?", 'Boys Over Flowers']}
# {'show_id': 's519', 'type': 'Movie', 'title': 'Har Kisse Ke Hisse: Kaamyaab', 'director': 'Hardik Mehta', 'cast': '"Sanjay Mishra', 'country': ' Deepak Dobriyal', 'date_added': ' Sarika Singh', 'release_year': ' Isha Talwar', 'rating': ' Avtar Gill', 'duration': ' Kaurwakee Vashistha', 'listed_in': ' Amitabh Srivastava', 'description': ' Vikas Verma"', 'recommendations': ['Bollywood Calling', 'What Happened to Mr. Cha?', 'Murder Mystery', 'The Forest of Love', 'Hasmukh']}
# {'show_id': 's520', 'type': 'TV Show', 'title': 'I AM A KILLER', 'director': '', 'cast': '', 'country': 'United Kingdom', 'date_added': '"July 6', 'release_year': ' 2021"', 'rating': '2020', 'duration': 'TV-MA', 'listed_in': '2 Seasons', 'description': '"British TV Shows', 'recommendations': ['Rectify', 'BAKI', '3 Deewarein', 'Women Behind Bars', 'The Confession Tapes']}
# {'show_id': 's521', 'type': 'TV Show', 'title': 'I Think You Should Leave with Tim Robinson', 'director': '', 'cast': '"Tim Robinson', 'country': ' Andy Samberg', 'date_added': ' Sam Richardson', 'release_year': ' Will Forte', 'rating': ' Fred Willard', 'duration': ' Cecily Strong', 'listed_in': ' Tim Heidecker', 'description': ' Kate Berlant"', 'recommendations': ['Monty Python: Before the Flying Circus', 'Stand Up and Away! with Brian Regan', 'The Who Was? Show', 'Netflix Presents: The Characters', 'COMEDIANS of the world']}
# {'show_id': 's522', 'type': 'TV Show', 'title': "Kim's Convenience", 'director': '', 'cast': '"Paul Sun-Hyung Lee', 'country': ' Jean Yoon', 'date_added': ' Andrea Bang', 'release_year': ' Simu Liu', 'rating': ' Andrew Phung', 'duration': ' Nicole Power"', 'listed_in': 'Canada', 'description': '"July 6', 'recommendations': ['Gook', 'Steel Rain', 'Hope Aur Hum', 'Because This Is My First Life', 'My Perfect Landing']}
# {'show_id': 's523', 'type': 'TV Show', 'title': 'Larva', 'director': '', 'cast': '', 'country': 'Russia', 'date_added': '"July 6', 'release_year': ' 2021"', 'rating': '2015', 'duration': 'TV-Y7', 'listed_in': '3 Seasons', 'description': '"Kids\' TV', 'recommendations': ['Creeped Out', "Sunday's Illness", 'Zubaan', 'Criminal Minds', 'Everyday Miracles']}
# {'show_id': 's524', 'type': 'TV Show', 'title': 'Marcella', 'director': '', 'cast': '"Anna Friel', 'country': ' Nicholas Pinnock', 'date_added': ' Sinéad Cusack', 'release_year': ' Nina Sosanya', 'rating': ' Harry Lloyd', 'duration': ' Laura Carmichael', 'listed_in': ' Maeve Dermody', 'description': ' Ray Panthaki', 'recommendations': ['La Mante', 'The Women and the Murderer', 'Hangman', 'Die Ontwaking', 'The Call']}
# {'show_id': 's525', 'type': 'TV Show', 'title': 'Midnight Diner: Tokyo Stories', 'director': '', 'cast': '"Kaoru Kobayashi', 'country': ' Joe Odagiri', 'date_added': ' Mansaku Fuwa', 'release_year': ' Reiko Kataoka', 'rating': ' Koen Kondo', 'duration': ' Bsaku Sato', 'listed_in': ' Hirofumi Arai', 'description': ' Mamiko Itoh', 'recommendations': ['2 Hearts', 'Ip Man', 'My Girl', 'The Bachelors', 'Dil Hai Tumhaara']}
# {'show_id': 's526', 'type': 'TV Show', 'title': 'My Little Pony: Friendship Is Magic', 'director': '', 'cast': '"Ashleigh Ball', 'country': ' Tabitha St. Germain', 'date_added': ' Tara Strong', 'release_year': ' Andrea Libman', 'rating': ' Cathy Weseluck', 'duration': ' Nicole Oliver"', 'listed_in': '"United States', 'description': ' Canada"', 'recommendations': ['My Little Pony Equestria Girls: Friendship Games', 'Shortcut Safari', 'Just Another Christmas', 'Tree House Tales', 'Project Papa']}
# {'show_id': 's527', 'type': 'TV Show', 'title': 'Orange Is the New Black', 'director': '', 'cast': '"Taylor Schilling', 'country': ' Kate Mulgrew', 'date_added': ' Laura Prepon', 'release_year': ' Jason Biggs', 'rating': ' Natasha Lyonne', 'duration': ' Michael Harney', 'listed_in': ' Uzo Aduba', 'description': ' Danielle Brooks', 'recommendations': ['Arrested Development', 'Queer Eye', 'House of Cards', 'Dean', 'Planet Earth II']}
# {'show_id': 's528', 'type': 'TV Show', 'title': 'Puffin Rock', 'director': '', 'cast': '"Chris O\'Dowd', 'country': ' Kate McCafferty', 'date_added': ' Sally McDaid', 'release_year': ' Geraldine Cole', 'rating': ' Brian McMonagle', 'duration': ' Darragh Gargan"', 'listed_in': '"Ireland', 'description': ' United States', 'recommendations': ['The Rugrats Movie', 'Earth to Luna!', 'My Little Pony: Friendship Is Magic', 'Locked on You', 'Two Fathers']}
# {'show_id': 's529', 'type': 'Movie', 'title': 'Rehmataan', 'director': '"Rajveer Singh Maan', 'cast': ' Harpeet Singh"', 'country': '"Guggu Gill', 'date_added': ' Sukhjinder Shera', 'release_year': ' Surinder Shinda', 'rating': ' Deep Dhillon', 'duration': ' Jasmine Jassi', 'listed_in': ' Gurvinder Brar', 'description': ' Razia Sukhvir', 'recommendations': ['The Pharmacist', 'Millennials', 'Extremely Wicked, Shockingly Evil and Vile', 'Nicky Jam: El Ganador', 'Justin Time GO!']}
# {'show_id': 's530', 'type': 'Movie', 'title': 'Return of the Prodigal Son', 'director': 'Youssef Chahine', 'cast': '"Majida El Roumi', 'country': ' Souheir El Morshidy', 'date_added': ' Shoukry Sarhan', 'release_year': ' Huda Sultan', 'rating': ' Mahmoud El Meleigy', 'duration': ' Ahmad Mehrez', 'listed_in': ' Hesham Selim"', 'description': 'Egypt', 'recommendations': ['Thriller', 'Kuppivala', 'Uncorked', 'Norman Lear: Just Another Version of You', '12 Years Promise']}
# {'show_id': 's531', 'type': 'TV Show', 'title': 'Richie Rich', 'director': '', 'cast': '"Jake Brennan', 'country': ' Joshua Carlon', 'date_added': ' Lauren Taylor', 'release_year': ' Jenna Ortega', 'rating': ' Kiff VandenHeuvel', 'duration': ' Brooke Wexler"', 'listed_in': 'United States', 'description': '"July 6', 'recommendations': ['Dragons: Dawn of the Dragon Racers', 'Pup Star', 'Barbie & Her Sisters in a Pony Tale', 'The Sleepover', 'Jem and the Holograms']}
# {'show_id': 's532', 'type': 'Movie', 'title': 'Rise: Ini Kalilah', 'director': '"Saw Teong Hin', 'cast': ' Nik Amir Mustapha', 'country': ' M.S. Prem Nath"', 'date_added': '"Remy Ishak', 'release_year': ' Mira Filzah', 'rating': ' Jack Tan', 'duration': ' Sangeeta Krishnasamy', 'listed_in': ' Shashi Tharan', 'description': " Mark O'Dea", 'recommendations': ['One Take', 'Seven', 'The Body Remembers When the World Broke Open', 'Story of an Egg', 'Fan of Amoory']}
# {'show_id': 's533', 'type': 'TV Show', 'title': 'Scream', 'director': '', 'cast': '"Willa Fitzgerald', 'country': ' Bex Taylor-Klaus', 'date_added': ' John Karna', 'release_year': ' Amadeus Serafini', 'rating': ' Connor Weil', 'duration': ' Carlson Young', 'listed_in': ' Jason Wiles', 'description': ' Tracy Middendorf', 'recommendations': ['Darr Sabko Lagta Hai', 'Bhoot', 'Hostel: Part III', 'Typewriter', 'Scream 3']}
# {'show_id': 's534', 'type': 'TV Show', 'title': 'Shtisel', 'director': '', 'cast': '"Doval\'e Glickman', 'country': ' Michael Aloni', 'date_added': ' Ayelet Zurer', 'release_year': ' Neta Riskin', 'rating': ' Shira Haas', 'duration': ' Sarel Piterman', 'listed_in': ' Zohar Shtrauss', 'description': ' Orly Silbersatz Banai', 'recommendations': ['My Unorthodox Life', 'One of Us', 'A Sun', 'Evening Shadows', 'Reply 1988']}
# {'show_id': 's535', 'type': 'Movie', 'title': 'Si Doel the Movie 2', 'director': 'Rano Karno', 'cast': '"Maudy Koesnaedi', 'country': ' Rano Karno', 'date_added': ' Cornelia Agatha', 'release_year': ' Mandra Naih', 'rating': ' Aminah Tjendrakasih', 'duration': ' Suty Karno', 'listed_in': ' Adam Jagwani"', 'description': 'Indonesia', 'recommendations': ['She Is', 'Si Doel the Movie 3', 'An Upper Egyptian', 'Ibrahim a Fate to Define', 'Dark Light']}
# {'show_id': 's536', 'type': 'TV Show', 'title': 'Some Assembly Required', 'director': '', 'cast': '"Kolton Stewart', 'country': ' Harrison Houde', 'date_added': ' Charlie Storwick', 'release_year': ' Sydney Scotia', 'rating': ' Travis Turner', 'duration': ' Ellie Harvie', 'listed_in': ' Dylan Playfair"', 'description': 'Canada', 'recommendations': ['Khelti Hai Zindagi Aankh Micholi', 'Copenhagen', 'Amateur', 'Azali', 'Jhansi Ki Rani']}
# {'show_id': 's537', 'type': 'TV Show', 'title': 'Tales by Light', 'director': '', 'cast': '"Darren Jew', 'country': ' Art Wolfe', 'date_added': ' Krystle Wright', 'release_year': ' Peter Eastway', 'rating': ' Richard l’Anson', 'duration': ' Jack Thompson', 'listed_in': ' Jonathan Scott', 'description': ' Angela Scott', 'recommendations': ['Hogie the Globehopper', 'Mauli', 'Conan Without Borders', 'Los tiempos de Pablo Escobar', 'Teresa']}
# {'show_id': 's538', 'type': 'TV Show', 'title': 'Terrace House: Opening New Doors', 'director': '', 'cast': '"You', 'country': ' Reina Triendl', 'date_added': ' Yoshimi Tokui', 'release_year': ' Azusa Babazono', 'rating': ' Ryota Yamasato', 'duration': ' Shono Hayama"', 'listed_in': 'Japan', 'description': '"July 6', 'recommendations': ['Ice Guardians', 'Aussie Gold Hunters', 'Love Is a Story', 'Running Man', 'Goon: Last of the Enforcers']}
# {'show_id': 's539', 'type': 'TV Show', 'title': 'The A List', 'director': '', 'cast': '"Lisa Ambalavanar', 'country': ' Ellie Duckles', 'date_added': ' Savannah Baker', 'release_year': ' Cian Barry', 'rating': ' Eleanor Bennett', 'duration': ' Jacob Dudman', 'listed_in': ' Rosie Dwyer', 'description': ' Jack Kane', 'recommendations': ['Fate: The Winx Saga', 'Jurassic World Camp Cretaceous', 'Zipi & Zape y la Isla del Capitan', 'Greenhouse Academy', 'The Decline']}
# {'show_id': 's540', 'type': 'TV Show', 'title': 'The New Legends of Monkey', 'director': '', 'cast': '"Chai Hansen', 'country': ' Luciane Buchanan', 'date_added': ' Josh Thomson', 'release_year': ' Emilie Cocquerel', 'rating': ' Josh McKenzie', 'duration': ' Jordan Mooney', 'listed_in': ' Jarred Blakiston"', 'description': '"Australia', 'recommendations': ['Chhota Bheem Aur Hanuman', 'The Book of Eli', 'Ice Fantasy', 'Clash of the Titans', 'Albion: The Enchanted Stallion']}
# {'show_id': 's541', 'type': 'TV Show', 'title': 'The Worst Witch', 'director': '', 'cast': '"Bella Ramsey', 'country': ' Clare Higgins', 'date_added': ' Meibh Campbell', 'release_year': ' Raquel Cassidy', 'rating': ' Jenny Richardson', 'duration': ' Miriam Petche', 'listed_in': ' Tallulah Milligan', 'description': ' Wendy Craig', 'recommendations': ['Luna Nera', 'The Craft', 'Undercover Brother 2', 'The Baby-Sitters Club', 'The Who Was? Show']}
# {'show_id': 's542', 'type': 'Movie', 'title': 'Truckbhar Swapna', 'director': 'Pramod Pawar', 'cast': '"Makrand Deshpande', 'country': ' Kranti Redkar', 'date_added': ' Mukesh Rishi', 'release_year': ' Manoj Joshi', 'rating': ' Smita Tambe', 'duration': ' Aaditi Pohankar', 'listed_in': ' Sahil Gilbile', 'description': ' Jyoti Joshi"', 'recommendations': ['Raja Hindustani', '\u200bGoli Soda 2', "We'll Be Right Back After The Break", 'Mumbai Cha Raja', 'When Hari Got Married']}
# {'show_id': 's543', 'type': 'Movie', 'title': 'Ujala', 'director': 'Naresh Saigal', 'cast': '"Mala Sinha', 'country': ' Shammi Kapoor', 'date_added': ' Raaj Kumar', 'release_year': ' Leela Chitnis', 'rating': ' Dhumal', 'duration': ' Kumkum"', 'listed_in': 'India', 'description': '"July 6', 'recommendations': ['Trespass Against Us', 'Kaminey', 'Kaviyude Osyath', 'Thambi', 'Miss Culinary']}
# {'show_id': 's544', 'type': 'TV Show', 'title': 'Undercover', 'director': '', 'cast': '"Tom Waes', 'country': ' Anna Drijver', 'date_added': ' Frank Lammers', 'release_year': ' Elise Schaap', 'rating': ' Raymond Thiry', 'duration': ' Kris Cuppens', 'listed_in': ' Kevin Janssens', 'description': ' Huub Smit"', 'recommendations': ['The Red Sea Diving Resort', 'Undercover Law', 'Brick Mansions', 'Happy Anniversary', 'Donnie Brasco']}
# {'show_id': 's545', 'type': 'TV Show', 'title': "Workin' Moms", 'director': '', 'cast': '"Catherine Reitman', 'country': ' Dani Kind', 'date_added': ' Juno Rinaldi', 'release_year': ' Jessalyn Wanlim', 'rating': ' Philip Sternberg', 'duration': ' Ryan Belleville', 'listed_in': ' Olunike Adeliyi', 'description': ' Dennis Andres', 'recommendations': ['Fun Mom Dinner', 'Set It Up', "Mother's Day", 'Bon Cop, Bad Cop', 'Little Things']}
# {'show_id': 's546', 'type': 'TV Show', 'title': 'YooHoo to the Rescue', 'director': '', 'cast': '"Kira Buckland', 'country': ' Ryan Bartley', 'date_added': ' Bryce Papenbrook', 'release_year': ' Cassandra Morris', 'rating': ' Lucien Dodge', 'duration': ' Kyle Hebert"', 'listed_in': 'South Korea', 'description': '"July 6', 'recommendations': ['Kipo and the Age of Wonderbeasts', 'Gilmore Girls', 'You vs. Wild', 'Rainbow Rangers', 'Bibik-Bibikku']}
# {'show_id': 's547', 'type': 'TV Show', 'title': 'You Are My Spring', 'director': '', 'cast': '"Seo Hyun-jin', 'country': ' Kim Dong-wook', 'date_added': ' Yoon Bak', 'release_year': ' Nam Gyu-ri', 'rating': ' Kim Ye-won', 'duration': ' Han Min', 'listed_in': ' Lee Hae-yeong', 'description': ' Ji Seung-hyun', 'recommendations': ['The Body Remembers When the World Broke Open', 'R.K.Nagar', 'Thumper', '\u200b\u200bKuch Bheege Alfaaz', 'Us and Them']}
# ...
# {'show_id': 's3156', 'type': 'Movie', 'title': 'The 9th Precinct', 'director': 'Ding-Lin Wang', 'cast': '"Roy Chiu', 'country': ' Chia-Chia Peng', 'date_added': ' Wen Chen-ling', 'release_year': ' Eugenie Liu', 'rating': ' Yeo Yann Yann"', 'duration': 'Taiwan', 'listed_in': '"December 13', 'description': ' 2019"', 'recommendations': ['Acts of Violence', 'Anjaan: Special Crimes Unit', 'Sakho & Mangane', 'Submission', 'Jiu Jitsu']}
# {'show_id': 's3157', 'type': 'Movie', 'title': 'Zero Hour', 'director': 'Robert O. Peters', 'cast': '"Richard Mofe-Damijo', 'country': ' Alex Ekubo', 'date_added': ' Ali Nuhu', 'release_year': ' Rahama Sadau', 'rating': ' Eucharia Anunobi', 'duration': ' Ene Oloja', 'listed_in': ' Halima Yusuf', 'description': ' Ayo Ayoola Ayolola"', 'recommendations': ['In Family We Trust', 'Mahmut & Meryem', 'The Golden Path', 'Dogs of Berlin', 'Seven']}
# {'show_id': 's3158', 'type': 'Movie', 'title': 'Jack Whitehall: Christmas with My Father', 'director': "Richard van't Riet", 'cast': '"Jack Whitehall', 'country': ' Michael Whitehall', 'date_added': ' Hugh Bonneville', 'release_year': ' Graham Norton', 'rating': ' Layton Williams', 'duration': ' Andrew Lloyd Webber', 'listed_in': ' Tim Rice', 'description': ' Tan France', 'recommendations': ['Jack Whitehall: Travels with My Father', "Jack Whitehall: I'm Only Joking", "Mariah Carey's Merriest Christmas", 'Jack Whitehall: At Large', 'An Unremarkable Christmas']}
# {'show_id': 's3159', 'type': 'Movie', 'title': 'The Sky Is Pink', 'director': 'Shonali Bose', 'cast': '"Rohit Saraf', 'country': ' Zaira Wasim', 'date_added': ' Farhan Akhtar', 'release_year': ' Priyanka Chopra"', 'rating': '"India', 'duration': ' United Kingdom', 'listed_in': ' Canada', 'description': ' United States"', 'recommendations': ['Notes for My Son', 'Hope Springs Eternal', 'Historia de un clan', 'Defiance', 'Extremely Wicked, Shockingly Evil and Vile']}
# {'show_id': 's3160', 'type': 'Movie', 'title': 'Good and Prosperous', 'director': 'Sameh Abdulaziz', 'cast': '"Ali Rabee', 'country': ' Mohamed Abdel-Rahman', 'date_added': ' Bayoumi Fouad', 'release_year': ' Karim Afifi', 'rating': ' Dalal Abdel Aziz', 'duration': ' Mai Selim', 'listed_in': ' Tara Emad', 'description': ' Mohammed Tharwat', 'recommendations': ['Harud', 'Hop', 'Street Flow', '#Rucker50', 'Choked: Paisa Bolta Hai']}
# {'show_id': 's3161', 'type': 'Movie', 'title': 'Michelle Wolf: Joke Show', 'director': 'Lance Bangs', 'cast': 'Michelle Wolf', 'country': 'United States', 'date_added': '"December 10', 'release_year': ' 2019"', 'rating': '2019', 'duration': 'TV-MA', 'listed_in': '60 min', 'description': 'Stand-Up Comedy', 'recommendations': ['Bill Burr: Paper Tiger', 'Pete Davidson: Alive From New York', 'The Break with Michelle Wolf', 'Whitney Cummings: Can I Touch It?', 'Ali Wong: Baby Cobra']}
# {'show_id': 's3162', 'type': 'Movie', 'title': 'A Family Reunion Christmas', 'director': 'Robbie Countryman', 'cast': '"Loretta Devine', 'country': ' Tia Mowry-Hardrict', 'date_added': ' Anthony Alabi', 'release_year': ' Talia Jackson', 'rating': ' Isaiah Russell-Bailey', 'duration': ' Cameron J. Wright', 'listed_in': ' Jordyn Raya James', 'description': ' Jackée Harry', 'recommendations': ['ChuChuTV Bedtime Stories & Moral Stories for Kids (English)', 'Power Rangers Samurai: Christmas Together, Friends Forever (Christmas Special)', 'Sparkle', 'Just Another Christmas', 'Shortcut Safari']}
# {'show_id': 's3163', 'type': 'Movie', 'title': 'It Comes at Night', 'director': 'Trey Edward Shults', 'cast': '"Joel Edgerton', 'country': ' Christopher Abbott', 'date_added': ' Carmen Ejogo', 'release_year': ' Riley Keough', 'rating': ' Kelvin Harrison Jr.', 'duration': ' David Pendleton', 'listed_in': ' Griffin Robert Faulkner"', 'description': 'United States', 'recommendations': ['La diosa del asfalto', 'Bangkok Hell', 'The Block Island Sound', 'Fallen', 'Stephanie']}
# {'show_id': 's3164', 'type': 'Movie', 'title': 'Saaho', 'director': 'Sujeeth', 'cast': '"Prabhas', 'country': ' Shraddha Kapoor', 'date_added': ' Jackie Shroff', 'release_year': ' Chunky Pandey', 'rating': ' Neil Nitin Mukesh', 'duration': ' Arun Vijay', 'listed_in': ' Vennela Kishore', 'description': ' Murli Sharma', 'recommendations': ['King of Boys', 'Echcharikkai', 'Black Money Love', 'Living in Bondage: Breaking Free', 'A Christmas Catch']}
# {'show_id': 's3165', 'type': 'Movie', 'title': 'Nothing to Lose 2', 'director': 'Alexandre Avancini', 'cast': '"Petrônio Gontijo', 'country': ' Day Mesquita', 'date_added': ' Beth Goulart', 'release_year': ' Dalton Vigh', 'rating': ' Eduardo Galvão', 'duration': ' César Mello', 'listed_in': ' Leonardo Franco', 'description': ' Raphael Viana', 'recommendations': ['Nothing to Lose', 'The Cravings', 'Ghanchakkar', 'Saadey CM Saab', 'The Bonfire of Destiny']}
# {'show_id': 's3166', 'type': 'TV Show', 'title': 'Astronomy Club: The Sketch Show', 'director': '', 'cast': '"Shawtane Bowen', 'country': ' Jonathan Braylock', 'date_added': ' Ray Cordova', 'release_year': ' Caroline Martin', 'rating': ' Jerah Milligan', 'duration': ' Monique Moses', 'listed_in': ' Keisha Zollar', 'description': ' James III"', 'recommendations': ["Monty Python's Almost the Truth", "Kevin Hart: I'm a Grown Little Man", 'Monty Python Conquers America', 'One Strange Rock', 'Karol Modzelewski, Łukasz „Lotek” Lodkowski No Offense']}
# {'show_id': 's3167', 'type': 'Movie', 'title': 'Banana Island Ghost', 'director': 'BB Sasore', 'cast': '"Chigul', 'country': ' Patrick Diabuah', 'date_added': ' Adetomiwa Edun', 'release_year': ' Uche Jumbo', 'rating': ' Saidi Balogun', 'duration': ' Ali Nuhu', 'listed_in': ' Bimbo Manuel', 'description': ' Akah Nnani', 'recommendations': ['The Sweetest Thing', 'Hayat Öpücügü', 'Hi Bye, Mama!', 'Look Out, Officer', 'Drink Drank Drunk']}
# {'show_id': 's3168', 'type': 'Movie', 'title': 'Celebrity Marriage', 'director': 'Pascal Amanfo', 'cast': '"Kanayo O. Kanayo', 'country': ' Tonto Dikeh', 'date_added': ' Jackie Appiah', 'release_year': ' Odunlade Adekola', 'rating': ' Toyin Aimakhu', 'duration': ' Osita Iheme', 'listed_in': ' Francis Odega', 'description': ' Calista Okoronkwo', 'recommendations': ['Mala Kahich Problem Nahi', 'An Imperfect Murder', 'Ride or Die', 'Love Is a Story', 'Sleepless Society: Two Pillows & A Lost Soul']}
# {'show_id': 's3169', 'type': 'TV Show', 'title': 'Fuller House', 'director': '', 'cast': '"Candace Cameron Bure', 'country': ' Jodie Sweetin', 'date_added': ' Andrea Barber', 'release_year': ' Michael Campion', 'rating': ' Elias Harger', 'duration': ' Soni Bringas', 'listed_in': ' Dashiell Messitt', 'description': ' Fox Messitt', 'recommendations': ['Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend', 'Man Like Mobeen', '2 Weeks in Lagos', 'Party Monster: Scratching the Surface', 'Manje Bistre']}
# {'show_id': 's3170', 'type': 'Movie', 'title': 'Marriage Story', 'director': 'Noah Baumbach', 'cast': '"Scarlett Johansson', 'country': ' Adam Driver', 'date_added': ' Laura Dern', 'release_year': ' Alan Alda', 'rating': ' Ray Liotta', 'duration': ' Julie Hagerty', 'listed_in': ' Merritt Wever', 'description': ' Azhy Robertson"', 'recommendations': ['20 Feet From Stardom', 'Social Distance', 'For the Love of Spock', 'Alejandro Sanz: What I Was Is What I Am', 'ROAD TO ROMA']}
# {'show_id': 's3171', 'type': 'Movie', 'title': 'No Game No Life: Zero', 'director': 'Atsuko Ishizuka', 'cast': '"Yoshitsugu Matsuoka', 'country': ' Ai Kayano', 'date_added': ' Yoko Hikasa', 'release_year': ' Yukari Tamura', 'rating': ' Yuka Iguchi', 'duration': ' Mamiko Noto', 'listed_in': ' Miyuki Sawashiro', 'description': ' Rie Kugimiya', 'recommendations': ['Underworld', 'Fate/Grand Order -First Order-', 'Awake', 'The Protector', 'Enter the Warriors Gate']}
# {'show_id': 's3172', 'type': 'Movie', 'title': 'Slow Country', 'director': 'Eric Aghimien', 'cast': '"Ivie Okujaye', 'country': ' Sambasa Nzeribe', 'date_added': ' Tope Tedela', 'release_year': ' Gina Castel', 'rating': ' Majid Michel', 'duration': ' Victor Erabie', 'listed_in': ' Brutus Richard', 'description': ' Adebayo Thomas"', 'recommendations': ['Mile 22', 'Polar', 'Pizza, birra, faso', 'Mean Dreams', 'The Chosen Ones']}
# {'show_id': 's3173', 'type': 'Movie', 'title': 'Spirit Riding Free: Spirit of Christmas', 'director': '', 'cast': '"Amber Frank', 'country': ' Bailey Gambertoglio', 'date_added': ' Sydney Park', 'release_year': ' Evan Agos', 'rating': ' Kay Bess', 'duration': ' Darcy Rose Byrnes', 'listed_in': ' David Faustino', 'description': ' Gabriella Graves', 'recommendations': ['Spark', 'Let It Snow', 'Mighty Express: A Mighty Christmas', "The Devil's Mistress", 'Fartsa']}
# {'show_id': 's3174', 'type': 'TV Show', 'title': 'Teasing Master Takagi-san', 'director': '', 'cast': '"Rie Takahashi', 'country': ' Yuki Kaji', 'date_added': ' Konomi Kohara', 'release_year': ' M・A・O', 'rating': ' Yui Ogura', 'duration': ' Yuma Uchida', 'listed_in': ' Kotori Koiwai', 'description': ' Nobuhiko Okamoto', 'recommendations': ['Fireworks', 'Switched', 'Love, Chunibyo & Other Delusions!', 'Rugal', 'Sailor Moon Crystal']}
# {'show_id': 's3175', 'type': 'TV Show', 'title': 'The Chosen One', 'director': 'Michel Tikhomiroff', 'cast': '"Paloma Bernardi', 'country': ' Renan Tenca', 'date_added': ' Gutto Szuster', 'release_year': ' Pedro Caetano', 'rating': ' Mariano Mattos Martins', 'duration': ' Alli Willow', 'listed_in': ' Kiko Vianello', 'description': ' Francisco Gaspar', 'recommendations': ['Munafik 2', 'The Oath', 'The Evil Dead', 'Z Nation', 'Bhangra Paa Le']}
# {'show_id': 's3176', 'type': 'TV Show', 'title': 'The Confession Killer', 'director': '"Robert Kenner', 'cast': ' Taki Oldham"', 'country': '', 'date_added': 'United States', 'release_year': '"December 6', 'rating': ' 2019"', 'duration': '2019', 'listed_in': 'TV-14', 'description': '1 Season', 'recommendations': ['Lost Girls', 'Elizabeth Harvest', 'The Haunting of Molly Hartley', 'May the Devil Take You', 'A Perfect Crime']}
# {'show_id': 's3177', 'type': 'TV Show', 'title': 'Three Days of Christmas', 'director': '', 'cast': '"Victoria Abril', 'country': ' Elena Anaya', 'date_added': ' Mar Ayala', 'release_year': ' Nerea Barros', 'rating': ' Berta Castañé', 'duration': ' Verónica Echegui', 'listed_in': ' Verónica Forqué', 'description': ' Ángela Molina', 'recommendations': ["JoJo's Bizarre Adventure", 'The Miracle', 'Camellia Sisters', 'Power Rangers Super Samurai: Stuck on Christmas', 'Engineering Girls']}
# {'show_id': 's3178', 'type': 'TV Show', 'title': 'Triad Princess', 'director': '', 'cast': '"Eugenie Liu', 'country': ' Jasper Liu', 'date_added': ' Cecilia Choi', 'release_year': ' Tien Hsin', 'rating': ' Michael JQ Huang', 'duration': ' Chang Zhang-xing', 'listed_in': ' Hung Yan-siang', 'description': ' Tsao Yu-ning', 'recommendations': ['The Crew', "My Boss's Daughter", 'Mindhorn', 'Fan Girl', 'Man to Man']}
# {'show_id': 's3179', 'type': 'Movie', 'title': 'Wives on Strike', 'director': 'Omoni Oboli', 'cast': '"Omoni Oboli', 'country': ' Kenneth Okonkwo', 'date_added': ' Kalu Ikeagwu', 'release_year': ' Uche Jumbo', 'rating': ' Ufoma Ejenobor', 'duration': ' Julius Agu', 'listed_in': ' Udoka Oyeka', 'description': ' Chioma Chukwuka-Akpotha', 'recommendations': ['The Vanished', 'Part-Time Idol', 'The Club', 'Seven (Telugu)', '7 (Seven)']}
# {'show_id': 's3180', 'type': 'Movie', 'title': 'Wives on Strike: The Revolution', 'director': 'Omoni Oboli', 'cast': '"Uche Jumbo', 'country': ' Omoni Oboli', 'date_added': ' Sola Sobowale', 'release_year': ' Chioma Chukwuka-Akpotha', 'rating': ' Ufuoma McDermott', 'duration': ' Odunlade Adekola', 'listed_in': ' Kalu Ikeagwu', 'description': ' Kenneth Okonkwo"', 'recommendations': ['August: Osage County', 'The Silence of Others', 'Zindagi Gulzar Hai', 'Fiddler on the Roof', 'Kiss the Girls']}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # consumer loop
# ----> 2 for message in consumer:
#       3     print(message.value)
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File c:\Users\jahir\AppData\Local\Programs\Python\Python311\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %% [markdown]
# ## For S3 bucket

# %%
# Function to read config from config.json
def read_config():
    try:
        with open('config.json', 'r') as config_file:
            config = json.load(config_file)
            return config
    except FileNotFoundError:
        print("Config file not found.")
        return None

# Function to upload data to AWS S3
def upload_to_s3(data):
    config = read_config()
    if config is None:
        return

    aws_access_key = config.get('aws_access_key', '')
    aws_secret_key = config.get('aws_secret_key', '')
    bucket_name = config.get('bucket_name', '')

    s3 = boto3.client('s3', aws_access_key_id=aws_access_key, aws_secret_access_key=aws_secret_key)

    try:
        unique_id = str(uuid.uuid4())
        json_data = json.dumps(data)

        s3.put_object(Bucket=bucket_name, Key=f'json_files/{unique_id}.json', Body=json_data)
        print(f"Data for ID {unique_id} uploaded to S3 successfully.")
    except NoCredentialsError:
        print("Credentials not available")

# %%
# Example consumer loop
for message in consumer:
    print(message.value)
    upload_to_s3(message.value)
    sleep(3)
